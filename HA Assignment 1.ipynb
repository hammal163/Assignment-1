# %%
a = 20
b = 5

print(a/b)
# Out:
# 4.0

# %%
name = "HAMMAL AKHTER"

print(name)
# Out:
# HAMMAL AKHTER

# %%
print(name.lower())
# Out:
# hammal akhter

# %%
string_variable = "hello world from python"

print(string_variable.title())
# Out:
# Hello World From Python

# %%
x = 10
y = 3

print(x%y)
# Out:
# 1

# %%
text = "PYTHON"

print(text.lower())
# Out:
# python

# %%
text = "data science"

print(len(text))
# Out:
# 12

# %%
num = 7

print(7**2)
# Out:
# 49

# %%
string = "Hello"

print(string*3)
# Out:
# HelloHelloHello

# %%
a = 15
b = 10

print(a>b)
# Out:
# True

# %%
variable_string = "i love python programming"

print(variable_string.capitalize())
# Out:
# I love python programming
